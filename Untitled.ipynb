# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

## Concatenate the Data Frames

X=pd.concat([X,geography,gender],axis=1)

## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#creating the neural network

#importing the lbiraires
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %% [markdown]
# #intitializing the ANN

# %%
classifier =  Sequential()
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform', activation = 'relu', input_dim = 11)) #this was the input layer
classifier.add(Dropout(0.2))
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform', activation = 'relu')) #this was the second layer
classifier.add(Dropout(0.3))
classifier.add(Dense(units = 1,kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # fitting our model with the training dataset

# %%
model_history =  classifier.fit(X_train, y_train, validation_split = 0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.6191 - accuracy: 0.7240 - val_loss: 0.5194 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5170 - accuracy: 0.7964 - val_loss: 0.4853 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4946 - accuracy: 0.7951 - val_loss: 0.4659 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4750 - accuracy: 0.7972 - val_loss: 0.4561 - val_accuracy: 0.7959
# Epoch 5/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4695 - accuracy: 0.8020 - val_loss: 0.4512 - val_accuracy: 0.8001
# Epoch 6/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4602 - accuracy: 0.8043 - val_loss: 0.4439 - val_accuracy: 0.7989
# Epoch 7/100
# ...

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred>0.5)
# Out:
# 63/63 [==============================] - 0s 792us/step

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)
score
# Out:
# 0.8635
